# %%
#1
import pandas as pd

df = pd.read_csv('Employee.csv')
print(df.loc[df["PaymentTier"]== 3])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 #1
#       2 import pandas as pd
# ----> 4 df = pd.read_csv('Employee.csv')
#       5 print(df.loc[df["PaymentTier"]== 3])
#
# ...

# %%
#2
print(df.iloc[:10,[0,3,4]])
# Out:
#    Education  PaymentTier  Age
# 0  Bachelors            3   34
# 1  Bachelors            1   28
# 2  Bachelors            3   38
# 3    Masters            3   27
# 4    Masters            3   24
# 5  Bachelors            3   22
# 6  Bachelors            3   38
# 7  Bachelors            3   34
# 8  Bachelors            3   23
# 9    Masters            2   37

# %%
#3
print(df.loc[(df['Gender'] == 'Female') & (df['ExperienceInCurrentDomain'] == 5)&(df['EverBenched'] == 'No')])
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 86    Bachelors         2017       Pune            2   27  Female          No
# 92    Bachelors         2017  New Delhi            2   34  Female          No
# 110   Bachelors         2015  Bangalore            3   27  Female          No
# 111   Bachelors         2017       Pune            2   27  Female          No
# 144   Bachelors         2013  Bangalore            3   27  Female          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4569        PHD         2017  New Delhi            3   31  Female          No
# 4596  Bachelors         2018  New Delhi            3   27  Female          No
# 4616    Masters         2015  New Delhi            3   40  Female          No
# 4628  Bachelors         2013  Bangalore            3   39  Female          No
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
#
# ...

# %%
#4
filtered_rows = df.loc[(df['JoiningYear'] >= 2016) & (df['JoiningYear'] <= 2018)]


result = filtered_rows.iloc[:, [df.columns.get_loc('City'), df.columns.get_loc('Age')]]

print(result)
# Out:
#            City  Age
# 0     Bangalore   34
# 3     Bangalore   27
# 4          Pune   24
# 5     Bangalore   22
# 7     Bangalore   34
# ...         ...  ...
# 4639  Bangalore   28
# 4641  Bangalore   33
# 4645       Pune   31
# 4647       Pune   30
# 4650  New Delhi   27
#
# [2000 rows x 2 columns]

# %%
#5
tp =df.loc[(df["PaymentTier"]==3)]
never_benched = tp['EverBenched']=='No'
benched = tp['EverBenched']=='Yes'
tp.loc[benched, 'SeniorityScore'] = tp.loc[benched, 'ExperienceInCurrentDomain'] * 1.5
tp.loc[never_benched, 'SeniorityScore'] = tp.loc[never_benched, 'ExperienceInCurrentDomain'] * 2



print(tp)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# 5     Bachelors         2016  Bangalore            3   22    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...
