# %%
import pandas as pd

dic = {"student ID":["s001","s002","s003","s004","s005","s006"],
       "Name":["Alice","Bob","Matt","Charlie","David","Emma"],
       "age": [19,21,25,20,22,19],
        "major":["comptuer sci","Math","IT","Physics","Bio","Econ"],
         "gpa":[3.8,3.5,3.6,3.9,3.2,3.7], 
         "scholarship":[True,False,False,True,False,True]}
df = pd.DataFrame(dic)
print (df)
# Out:
#   student ID     Name  age         major  gpa  scholarship
# 0       s001    Alice   19  comptuer sci  3.8         True
# 1       s002      Bob   21          Math  3.5        False
# 2       s003     Matt   25            IT  3.6        False
# 3       s004  Charlie   20       Physics  3.9         True
# 4       s005    David   22           Bio  3.2        False
# 5       s006     Emma   19          Econ  3.7         True

# %%
print(df.iloc[2])
# Out:
# student ID      s003
# Name            Matt
# age               25
# major             IT
# gpa              3.6
# scholarship    False
# Name: 2, dtype: object

# %%
marks =83+41
marks= marks/2
print(marks)
# Out:
# 62.0
